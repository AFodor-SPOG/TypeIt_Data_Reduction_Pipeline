# %% [markdown]
# Run each cell individually. Some file might snag this code and will stop it from deleting everything else that it can still delete.

# %%
#These are the python packages that are needed for the full code. If you get an error, that means some package
#must be installed on python

from astropy.io import fits
import astropy
import matplotlib.pyplot as plt
import numpy as np
import datetime
import glob
from scipy.optimize import curve_fit
from numpy import loadtxt
from matplotlib.backends.backend_pdf import PdfPages
from astropy import units as u
from astropy.io.fits import Header
import os
import astropy.stats as ap
from astropy.io import fits
from astropy.modeling import models, fitting
from astropy.modeling.models import custom_model
from astropy.modeling import Fittable1DModel, Parameter
#from astroquery.sdss import SDSS
import pandas as pd
import matplotlib.pyplot as plt
from scipy import interpolate
import numpy as np
import math
import numpy.polynomial.polynomial as poly
#from astroquery.sdss import SDSS

# %%
import os
import glob
import os
import sys
import shutil

# %% [markdown]
# The purpose of this code is to erase all working files inside of the data reduction folders. Ideally, this is to wipe work before starting a new run on that night.
#
# Note: This isn't needed to reduce multiple galaxies from an observing night. This is in case of testing things/re-reducing

# %%
#     ||
#     ||
#     ||
#     ||
#     ||
#     ||
#     ||     Here you go, sweep
#     ||     that up..............
#    /||\
#   /||||\
#   ======         __|__
#   ||||||        / ~@~ \
#   ||||||       |-------|
#   ||||||       |_______|

# %%
#In this cell, we will be changing the inputs required throughout the rest of the pipeline
path = "/Users/afodo/Desktop/Remote Work/LDT-Pipeline/"#This is the file path to the main reduction
galaxy_name = "J2159-0749_minor" #Using our observing logs, this is the galaxy's name that we want to reduce
galaxy_name_2 = "J2159-0749"  
galaxy_file_name = galaxy_name #Same as last line (Artifact of a past code that needed 2)
standard_star_name = "LDS749B" #Standard star name (Also observed right before/after our galaxy)
date = "8-23" #observation date as a number
date_link = "Aug 23 2019" # observation date
RA = 329.8845 #galaxy's RA value from SPOGs catalog
Dec = -7.8237 #galaxy's Dec value from SPOGs catalog
setting = "B" #Should be an A or B. This refers to the wavelength range observed.

# %%
files = glob.glob(path + "Observations/"+ date_link +"/Trimmed Data/*.fits")

for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Observations/"+ date_link +"/Trimmed Data/Bias Subtracted/*.fits")

for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Observations/"+ date_link +"/Trimmed Data/Bias Subtracted/"+ setting +"/*.fits")

for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Observations/"+ date_link +"/Trimmed Data/Bias Subtracted/"+ setting +"/Sky and Wavelength Work/*.fits")

for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Observations/"+ date_link +"/Trimmed Data/Bias Subtracted/"+ setting +"/Sky and Wavelength Work/Spectra Txt/*.txt")

for f in files:
    os.remove(f)

# %%
#files = glob.glob(path + "3D Output Cubes Unbinned/*.fits")

#for f in files:
 #   os.remove(f)

# %%
files = glob.glob(path + "Working Files/Dome Flat Fit/*.jpg")

for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Flux Calibration/*.jpg")
files2 = glob.glob(path + "Working Files/Flux Calibration/*.pdf")

for f in files:
    os.remove(f)
    
for g in files2:
    os.remove(g)

# %%
files = glob.glob(path + "Working Files/Sky Subtracted/*.pdf")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Temp Cubes/*.fits")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Wavelength Fits/*.pdf")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/3D Cube/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Centering/*")


for f in files:
    shutil.rmtree(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Dome Division/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Dome.Science Raw Error/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Master Bias/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Master Dome/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Median Combined Science Error/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Sky Subtraction/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Error Propagation/Flux Calibration/*.jpg")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Observations/"+date_link+"/LOGFILE/*")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Sky-Subtracted/*.pdf")


for f in files:
    os.remove(f)

# %%
files = glob.glob(path + "Working Files/Binning/*")


for f in files:
    shutil.rmtree(f)

# %%
files = glob.glob(path + "Working Files/Extinction/*")


for f in files:
    shutil.rmtree(f)

# %%
files = glob.glob(path + "Working Files/SDSS Comparison/*")


for f in files:
    shutil.rmtree(f)
